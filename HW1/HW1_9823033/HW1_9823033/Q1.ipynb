# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Q1_coverting to data frame
smartphones = pd.read_csv("C:/Users/acer/Desktop/HW1_9823033/Smartphone.csv")
print(smartphones)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
#Q2_number of rrows and columns
smartphones.shape
# Out:
# (2000, 21)

# %%
#Q2_number of data in each column
smartphones.describe().iloc[0]
# Out:
# battery_power    2000.0
# blue             2000.0
# clock_speed      2000.0
# dual_sim         2000.0
# fc               2000.0
# four_g           2000.0
# int_memory       2000.0
# m_dep            2000.0
# mobile_wt        2000.0
# n_cores          2000.0
# pc               2000.0
# px_height        2000.0
# px_width         2000.0
# ram              2000.0
# sc_h             2000.0
# sc_w             2000.0
# talk_time        2000.0
# three_g          2000.0
# touch_screen     2000.0
# wifi             2000.0
# price_range      2000.0
# Name: count, dtype: float64

# %%
#Q2_data type of each column
result = smartphones.dtypes
print(result)
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
#Q2_volume of datafram
smartphone_size = smartphones.size
print(smartphone_size)
# Out:
# 42000

# %%
#Q3
smartphones.loc[(smartphones.blue == 1) & (smartphones.int_memory > 10)]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 4              1821     1          1.2         0  13       1          44
# 8              1445     1          0.5         0   0       0          53
# 11             1520     1          2.2         0   5       1          33
# ...             ...   ...          ...       ...  ..     ...         ...
# 1990           1617     1          2.4         0   8       1          36
# 1992            674     1          2.9         1   1       0          21
# 1993           1467     1          0.5         0   0       0          18
# 1996           1965     1          2.6         1   0       0          39
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
#Q4
smartphone1=smartphones.describe()

strong=smartphone1.loc["max","fc"]
weak=smartphone1.loc["min","fc"]
print(strong)
print(weak)
smartphones.loc[(smartphones.fc == strong) | (smartphones.fc == weak)]
# Out:
# 19.0
# 0.0
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1              1021     1          0.5         1   0       1          53
# 3               615     1          2.5         0   0       0          10
# 7              1954     0          0.5         1   0       0          24
# 8              1445     1          0.5         0   0       0          53
# 10              769     1          2.9         1   0       0           9
# ...             ...   ...          ...       ...  ..     ...         ...
# 1971            538     0          1.1         1   0       1          25
# 1984            797     0          2.2         1   0       0          37
# 1993           1467     1          0.5         0   0       0          18
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
#Q5
smartphones.insert(0,"clock_rate", " ")

for x in range(smartphones.shape[0]):
    if smartphones.iloc[x,3] <= 1:
        smartphones.iloc[x,0]="Low"
    elif smartphones.iloc[x,3] < 2:
        smartphones.iloc[x,0]="Mid"
    else:
        smartphones.iloc[x,0]="High"
print(smartphones)
# Out:
#      clock_rate  battery_power  blue  clock_speed  dual_sim  fc  four_g  \
# 0          High            842     0          2.2         0   1       0
# 1           Low           1021     1          0.5         1   0       1
# 2           Low            563     1          0.5         1   2       1
# 3          High            615     1          2.5         0   0       0
# 4           Mid           1821     1          1.2         0  13       1
# ...         ...            ...   ...          ...       ...  ..     ...
# 1995        Low            794     1          0.5         1   0       1
# 1996       High           1965     1          2.6         1   0       0
# 1997        Low           1911     0          0.9         1   1       1
# 1998        Low           1512     0          0.9         0   4       1
# 1999       High            510     1          2.0         1   5       1
#
#       int_memory  m_dep  mobile_wt  ...  px_height  px_width   ram  sc_h  \
# ...

# %%
#Q7
sns.histplot(smartphones["battery_power"], color = "green")
# Out:
# <AxesSubplot:xlabel='battery_power', ylabel='Count'>

# %%
#Q6
plot=sns.heatmap(smartphones.corr(),annot=True)
#strong relationship------
#[fc,pc] , [three_g,four_g] , [ram,price_range], [sc_h,sc_w] , [px_height,px_width]
